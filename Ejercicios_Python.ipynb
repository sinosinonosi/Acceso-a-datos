# %% [markdown]
# <a href="https://colab.research.google.com/github/sinosinonosi/Acceso-a-datos/blob/main/Ejercicios_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**
#
# ---

# %% [markdown]
# Escribe un programa que llame 2 veces a la función print() para mostrar en líneas separadas tu nombre completo. En la 1ra línea aparecerá el nombre y en la siguiente los apellidos.

# %%
print("Enric")
print("Pruñonosa Sánchez")
# Out:
# Enric
# Pruñonosa Sánchez

# %% [markdown]
# # **Ejercicio 2**
#
# ---

# %% [markdown]
# Modifica el programa anterior para que el nombre y los apellidos se muestren en la misma línea. Sigue llamando 2 veces a la función print(). Usa el parámetro end.

# %%
print("Enric", end=" ")
print("Pruñonosa Sánchez")
# Out:
# Enric Pruñonosa Sánchez

# %% [markdown]
# # **Ejercicio 3**
#
# ---

# %% [markdown]
# Con un solo print() muestra tu nombre completo de forma que entre cada palabra aparezca un guión bajo o underscore ("_"). Usa el parámetro sep.

# %%
print("Enric", "Pruñonosa", "Sánchez", sep="_")
# Out:
# Enric_Pruñonosa_Sánchez

# %% [markdown]
# # **Ejercicio 4**
#
# ---

# %% [markdown]
# Modifica el programa anterior para que usando algún código de escape se muestre una palabra por línea. Sólo debes usar un print().

# %%
print("Enric", "Pruñonosa", "Sánchez", sep="\n")
# Out:
# Enric
# Pruñonosa
# Sánchez

# %% [markdown]
# # **Ejercicio 5**
#
# ---

# %% [markdown]
# Modifica el programa anterior para añadir tu número de teléfono en una nueva línea. Sólo debes usar un print().

# %%
print("Enric", "Pruñonosa", "Sánchez","123456789", sep="\n")
# Out:
# Enric
# Pruñonosa
# Sánchez
# 123456789

# %% [markdown]
# # **Ejercicio 6**
#
# ---

# %% [markdown]
# Escribe en 2 columnas una lista de elementos. En la columna de la izquierda aparecerá el nombre de un producto y en la de la derecha su precio en euros (con decimales). Las palabras deben estar alineadas a la izquierda. Usa colores diferentes para los títulos de columna, para las frutas y para los importes.
#
#
# ![Lista.png](data:image/png;base64,...)

# %%
print('\033[34m'+"Producto"+'\033[0m'+"|"+'\033[34m'+"Precio(€)")
print('\033[0m'+"--------|---------")
print('\033[95m'+"Manzana "+'\033[0m'+"|"+'\033[33m'+"0.50")
print('\033[95m'+"Plátano "+'\033[0m'+"|"+'\033[33m'+"0.30")
print('\033[95m'+"Naranja "+'\033[0m'+"|"+'\033[33m'+"0.40")
print('\033[95m'+"Pera    "+'\033[0m'+"|"+'\033[33m'+"0.60")
print('\033[95m'+"Mango   "+'\033[0m'+"|"+'\033[33m'+"1.20")
# Out:
# Producto|Precio(€)
# --------|---------
# Manzana |0.50
# Plátano |0.30
# Naranja |0.40
# Pera    |0.60
# Mango   |1.20

# %% [markdown]
# # **Ejercicio 7**
#
# ---

# %% [markdown]
# Escribe un programa que calcule el precio final de un producto según:
#
# • La base imponible (precio antes de impuestos)
#
# • El tipo de IVA aplicado. Puede ser: general (21%), reducido (10%) o superreducido (4%).
#
# • El código promocional. Los códigos promocionales pueden ser: sinpromo (no se aplica promoción), mitad (el precio se reduce a la mitad), descfijo (se descuentan 5 euros) o porcentaje (se descuenta el 5%).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
base = int(input("Introduzca la base imponible:  "))
tipo = input("Introduzca el tipo de IVA (general, reducido o superreducido):  ")
if tipo == "general":
  iva = 0.21
elif tipo == "reducido":
  iva = 0.10
elif tipo == "superreducido":
  iva = 0.04
else:
  iva = 0 # Default IVA if input is invalid

codigo = input("Introduzca el código promocional (sinpromo, mitad, descfijo o porcentaje):  ")

precio_con_iva = base + base * iva
descuento_aplicado = 0

if codigo == "sinpromo":
  descuento_aplicado = 0
elif codigo == "mitad":
  descuento_aplicado = precio_con_iva * 0.5
elif codigo == "descfijo":
  descuento_aplicado = 5
elif codigo == "porcentaje":
  descuento_aplicado = precio_con_iva * 0.05
else:
  print("Código promocional no válido. No se aplicará descuento.")

precio_final = precio_con_iva - descuento_aplicado

print("Base imponible               ", base)
print("IVA                          ", iva * 100, "%")
print("Precio con IVA               ", precio_con_iva)
print("Código promocional aplicado  ", codigo)
print("Descuento aplicado           ", "-",descuento_aplicado)
print("Precio final                 ", precio_final)
# Out:
# Introduzca la base imponible:  24
# Introduzca el tipo de IVA (general, reducido o superreducido):  general
# Introduzca el código promocional (sinpromo, mitad, descfijo o porcentaje):  descfijo
# Base imponible                24
# IVA                           21.0 %
# Precio con IVA                29.04
# Código promocional aplicado   descfijo
# Descuento aplicado            5
# Precio final                  24.04

# %% [markdown]
# # **Ejercicio 8**
#
# ---

# %% [markdown]
# Realiza un programa que:
#
#
# *   Pida números hasta que se introduzca un numero negativo
# *   Tras introducir un número negativo el programa deberá mostrar:
#     * Cuantos números se han introducido,
#     * la media de los impares y
#     * el mayor de los pares.
#
# El número negativo sólo se utiliza para indicar el final de la introducción de datos pero no se incluye en los cálculos.

# %%
print("Pon números positivos y para finalizar pon uno negativo")

count = 0
sum_odd = 0
count_odd = 0
largo = 0

while True:
    num = int(input())
    if num < 0:
        break
    count += 1
    if num % 2 != 0:
        sum_odd += num
        count_odd += 1
    else:
        if largo is None or num > largo:
            largo = num

print("Números introducidos:", count)
if count_odd > 0:
    print("Media de impares:", sum_odd / count_odd)
else:
    print("No se introdujeron números impares.")

if largo is not None:
    print("Mayor de los pares:", largo)
else:
    print("No se introdujeron números pares.")
# Out:
# Pon números positivos y para finalizar pon uno negativo
# 23
# 5
# 1
# 2
# 67
# 5
# -3
# Números introducidos: 6
# Media de impares: 20.2
# Mayor de los pares: 2

# %% [markdown]
# # **Ejercicio 9**
#
# ---

# %% [markdown]
# Realiza un programa que intente adivinar una contraseña que el sistema conoce (la que tu decidas). Hay 3 oportunidades para conseguirlo. En cada intento fallido, el programa debe preguntar si quieres continuar o abandonar. Al finalizar los 3 intentos, si no se ha adivinado la contraseña debe aparecer un mensaje que indique que la cuenta se ha bloqueado, y que se debe contactar con el administrador para reactivarla.

# %%
password = "HolaMundo1234"
attempts = 0
max_attempts = 3

while attempts < max_attempts:
    guess = input("Introduce la contraseña: ")
    attempts += 1
    if guess == password:
        print("¡Contraseña correcta!")
        break
    else:
        print("Contraseña incorrecta.")
        if attempts < max_attempts:
            continue_game = input("¿Quieres intentarlo de nuevo? (s/n): ")
            if continue_game.lower() != "s":
                print("Juego terminado por el usuario.")
                break
        else:
            print("Demasiados intentos fallidos. Cuenta bloqueada.")
            print("Contacta con el administrador para reactivarla.")
# Out:
# Introduce la contraseña: hola
# Contraseña incorrecta.
# ¿Quieres intentarlo de nuevo? (s/n): s
# Introduce la contraseña: hola
# Contraseña incorrecta.
# ¿Quieres intentarlo de nuevo? (s/n): s
# Introduce la contraseña: mysecretpassword
# ¡Contraseña correcta!

# %% [markdown]
# # **Ejercicio 10**
#
# ---

# %% [markdown]
# Escribe un programa que pida 8 palabras y las almacene en un array. A continuación, las
# palabras correspondientes a colores se deben almacenar al comienzo y las que no son colores
# a continuación. Los colores que conoce el programa deben estar en otro array y son los siguientes: verde, rojo, azul, amarillo, naranja, rosa, negro, blanco y morado.

# %%
colores_conocidos = ["verde", "rojo", "azul", "amarillo", "naranja", "rosa", "negro", "blanco", "morado"]
palabras = []
colores = []
no_colores = []

print("Introduce 8 palabras:")
for i in range(8):
    palabra = input(f"Palabra {i+1}: ")
    palabras.append(palabra)

for palabra in palabras:
    if palabra.lower() in colores_conocidos:
        colores.append(palabra)
    else:
        no_colores.append(palabra)

array_ordenado = colores + no_colores
print("\nArray original:", palabras)
print("Array ordenado (colores primero):", array_ordenado)

# %% [markdown]
# # **Ejercicio 11**
#
# ---

# %% [markdown]
# Crea una función para el ejercicio 7. La función deberá recibir los siguientes parámetros (base imponible, tipo de IVA y código promocional) y mostrará por pantalla la información correspondiente.
#
# Crea una función para el ejercicio 10 que reciba como parámetro la password de sistema (que el usuario deberá intentar adivinar). La función deberá devolver un string que indique si se ha adinidado la contraseña o no, cuántos intentos se han realizado y si se ha bloqueado la cuenta (sólo en caso de que no se acierte la password)
#
# Crea un programa principal que llame a estas funciones. Hazlo mediante un menú de 2 opciones, más una 3ra para "Salir".
#
# El programa principal deberá interaccionar con el usuario (si es necesario) para obtener los parámetros de entrada que se necesiten y, en el caso del ejercicio 10, deberá recoger el string retornado y mostrarlo por pantalla.

# %%
print("No me da tiempo")

# %% [markdown]
# # **Ejercicio 13**
#
# ---

# %% [markdown]
# Crea la clase coche de M3 en Python

# %%
print("No me da tiempo")
